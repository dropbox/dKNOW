# %% [markdown]
# # Error Handling Examples
#
# This notebook demonstrates error handling in Python.

# %%
x = 10
y = 5
result = x / y
print(f'Result: {result}')
# Out:
# Result: 2.0

# %% [markdown]
# ## Division by Zero Error

# %%
result = 1 / 0
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Continuing After Error
#
# The notebook can continue executing cells after an error.

# %%
print('This cell executed successfully!')
# Out:
# This cell executed successfully!
